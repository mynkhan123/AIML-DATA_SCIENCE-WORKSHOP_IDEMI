# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Airbnb NYC 2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7391 entries, 0 to 7390
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7391 non-null   int64
#  1   name                            7384 non-null   object
#  2   host_id                         7391 non-null   int64
#  3   host_name                       7386 non-null   object
#  4   neighbourhood_group             7391 non-null   object
#  5   neighbourhood                   7391 non-null   object
#  6   latitude                        7391 non-null   float64
#  7   longitude                       7391 non-null   float64
#  8   room_type                       7390 non-null   object
#  9   price                           7390 non-null   float64
#  10  minimum_nights                  7390 non-null   float64
#  11  number_of_reviews               7390 non-null   float64
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
## Renaming Few Columns name
df = df.rename(columns={'id':'listing_id', 'name':'listing_name', 'number_of_reviews':'total_reviews',
                        'calculated_host_listings_count':'host_listing_count'})

# %%
df.columns
# Out:
# Index(['listing_id', 'listing_name', 'host_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'total_reviews', 'last_review',
#        'reviews_per_month', 'host_listing_count', 'availability_365'],
#       dtype='object')

# %%
df.head()
# Out:
#    listing_id                                      listing_name  host_id  \
# 0        2539                Clean & quiet apt home by the park     2787
# 1        2595                             Skylit Midtown Castle     2845
# 2        3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3        3831                   Cozy Entire Floor of Brownstone     4869
# 4        5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  total_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (7391, 16)

# %%
## Droping Columns
df = df.drop(['last_review'], axis=1)

# %%
df.columns
# Out:
# Index(['listing_id', 'listing_name', 'host_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'total_reviews',
#        'reviews_per_month', 'host_listing_count', 'availability_365'],
#       dtype='object')

# %%
df[20:51]
# Out:
#     listing_id                                       listing_name  host_id  \
# 20        7801                   Sweet and Spacious Brooklyn Loft    21207
# 21        8024                     CBG CtyBGd HelpsHaiti rm#1:1-4    22486
# 22        8025                           CBG Helps Haiti Room#2.5    22486
# 23        8110                              CBG Helps Haiti Rm #2    22486
# 24        8490             MAISON DES SIRENES1,bohemian apartment    25183
# 25        8505                 Sunny Bedroom Across Prospect Park    25326
# 26        8700  Magnifique Suite au N de Manhattan - vue Cloitres    26394
# 27        9357                               Midtown Pied-a-terre    30193
# 28        9518       SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM    31374
# 29        9657                   Modern 1 BR / NYC / EAST VILLAGE    21904
# 30        9668                              front room/double bed    32294
# ...

# %%
## Saving DataFrame to a CSV file
df.to_excel('updated_Airbnb_NYC_2019.xlsx')

# %%
## Cleaning the Data
df.isnull().sum()
# Out:
# listing_id               0
# listing_name             7
# host_id                  0
# host_name                5
# neighbourhood_group      0
# neighbourhood            0
# latitude                 0
# longitude                0
# room_type                1
# price                    1
# minimum_nights           1
# total_reviews            1
# reviews_per_month      824
# host_listing_count       1
# availability_365         1
# dtype: int64

# %%
## Creating a sample Dataframe with null values
data = {
    'c1':[10,20,30,np.nan,50],
    'c2':[100,200,300,400,np.nan],
    'c3':[np.nan, 70,90,100,110]
}

df1 = pd.DataFrame(data)

# %%
print("Original DataFrame:")
print(df1)
# Out:
# Original DataFrame:
#      c1     c2     c3
# 0  10.0  100.0    NaN
# 1  20.0  200.0   70.0
# 2  30.0  300.0   90.0
# 3   NaN  400.0  100.0
# 4  50.0    NaN  110.0

# %%
df1.isnull().sum()
# Out:
# c1    1
# c2    1
# c3    1
# dtype: int64

# %%
df1 = df1.dropna()
print("After Using dropna command:")
print(df1)
# Out:
# After Using dropna command:
#      c1     c2    c3
# 1  20.0  200.0  70.0
# 2  30.0  300.0  90.0

# %%
## filling nullvalues with specific value
df1=df1.fillna(0)
print("After Filling 0 in null values:")
print(df1)
# Out:
# After Filling 0 in null values:
#      c1     c2    c3
# 1  20.0  200.0  70.0
# 2  30.0  300.0  90.0

# %%
## Replacing Null Values with the mean of the column
df1 = df1.fillna(df1.mean())
print("After Filling Mean in null values:")
print(df1)
# Out:
# After Filling Mean in null values:
#      c1     c2    c3
# 1  20.0  200.0  70.0
# 2  30.0  300.0  90.0

# %%
sns.boxplot(x=df1['c2'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7391 entries, 0 to 7390
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           7391 non-null   int64
#  1   listing_name         7384 non-null   object
#  2   host_id              7391 non-null   int64
#  3   host_name            7386 non-null   object
#  4   neighbourhood_group  7391 non-null   object
#  5   neighbourhood        7391 non-null   object
#  6   latitude             7391 non-null   float64
#  7   longitude            7391 non-null   float64
#  8   room_type            7390 non-null   object
#  9   price                7390 non-null   float64
#  10  minimum_nights       7390 non-null   float64
#  11  total_reviews        7390 non-null   float64
#  12  reviews_per_month    6567 non-null   float64
#  13  host_listing_count   7390 non-null   float64
#  14  availability_365     7390 non-null   float64
# ...

# %%
df['listing_name'].fillna('Unknown', inplace=True)
df['host_name'].fillna('no_name', inplace=True)

# %%
## so the null values are removed
df[['host_name', 'listing_name']].isnull().sum()
# Out:
# host_name       0
# listing_name    0
# dtype: int64

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(0).astype(int)

# %%
df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7391 entries, 0 to 7390
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           7391 non-null   int64
#  1   listing_name         7391 non-null   object
#  2   host_id              7391 non-null   int64
#  3   host_name            7391 non-null   object
#  4   neighbourhood_group  7391 non-null   object
#  5   neighbourhood        7391 non-null   object
#  6   latitude             7391 non-null   float64
#  7   longitude            7391 non-null   float64
#  8   room_type            7390 non-null   object
#  9   price                7390 non-null   float64
#  10  minimum_nights       7390 non-null   float64
#  11  total_reviews        7390 non-null   float64
#  12  reviews_per_month    7391 non-null   int64
#  13  host_listing_count   7390 non-null   float64
#  14  availability_365     7390 non-null   float64
# ...

# %%
## Describe the Dataset and removing Outliers
df.describe() # Descriptive Statistics
# Out:
#          listing_id       host_id     latitude    longitude        price  \
# count  7.391000e+03  7.391000e+03  7391.000000  7391.000000  7390.000000
# mean   2.443569e+06  7.922206e+06    40.729248   -73.950496   167.145873
# std    1.689463e+06  7.639974e+06     0.051749     0.779693   278.992369
# min    2.539000e+03  2.571000e+03    40.508680   -74.239860    10.000000
# 25%    8.227680e+05  1.599930e+06    40.688775   -73.984005    80.000000
# 50%    2.224896e+06  5.076827e+06    40.723220   -73.959300   120.000000
# 75%    4.032019e+06  1.198219e+07    40.763785   -73.943620   185.000000
# max    5.478741e+06  4.139808e+07    40.908040    -7.000000  9999.000000
#
#        minimum_nights  total_reviews  reviews_per_month  host_listing_count  \
# count     7390.000000    7390.000000        7391.000000         7390.000000
# mean         8.530717      50.785792           0.492085            2.636130
# std         29.761734      72.709536           1.010050            6.907491
# ...

# %%
sns.boxplot(x=df['price'])
plt.show()
print(df.shape)
# Out:
# (48895, 16)

# %%
## Removing Outliers
def iqr_tech(Dfcolumn):
  Q1 = np.percentile(Dfcolumn, 25)
  Q3 = np.percentile(Dfcolumn, 75)
  IQR = Q3 - Q1
  upper_range = Q3 + (1.5 * IQR)
  lower_range = Q1 - (1.5 * IQR)

  return upper_range, lower_range

# %%
lower_bound,upper_bound = iqr_tech(df['price'])

# %%
df = df[(df.price > lower_bound) & (df.price > upper_bound)]

# %%
sns.boxplot(x=df['price'])
plt.show()
print(df.shape)
# Out:
# (20, 16)

# %%
df.shape
# Out:
# (48895, 16)

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## Data Visualizations

# %%
# 1) Distribution of Airbnb Booking Price Using Histogram(Distplot)
plt.figure(figsize=(12,6))
sns.set_theme(style='whitegrid')
sns.distplot(df['price'], color='red')
plt.title('Distribution of Airbnb Booking Price', fontsize=20)
plt.xlabel('Price', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.show()
# Out:
# <ipython-input-65-3639a70682bc>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], color='red')

# %%
## Count the  number of listings in each neighbourhood group
counts = df['neighbourhood_group'].value_counts()
print(counts)
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
Top_neighbourhood_group = counts.reset_index()
Top_neighbourhood_group.columns = ['Neighbourhood_group', 'Listing_count']
Top_neighbourhood_group
# Out:
#   Neighbourhood_group  Listing_count
# 0           Manhattan          21661
# 1            Brooklyn          20104
# 2              Queens           5666
# 3               Bronx           1091
# 4       Staten Island            373

# %%
sns.countplot(x='neighbourhood_group', data=df)
plt.show()

# %%
## ## Avrage Price by Neighbourhood Group
from statistics import mean
sns.pointplot(x='neighbourhood_group', y='price', data=df, estimator=np.mean)
plt.title("Average Price by Neighbourhood Group")
plt.show()

# %%
## AVrage Price of Each Neighbourhood Group Using violin Plot
sns.violinplot(x='neighbourhood_group', y='price', data=df)
plt.show()
